# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = np.loadtxt('output.txt')

# %%
t = data[:, 0]
x = data[:, 1]
v = data[:, 4]
sig = data[:, 5]
ana_v = data[:, 6]
ana_sig = data[:, 7]
sig_err = data[:, -1]
u_err = data[:, -2]

# %%
plt.plot(t, sig_err)

# %%
plt.plot(t, u_err)

# %%
plt.plot(x, ana_v)

# %%
plt.plot(x, ana_v)

# %%
plt.plot(t, v, 'bo', markersize=1)
plt.xlim([0, 5])
plt.ylim([-5, 5])
# Out:
# (-5, 5)

# %%
plt.plot(t, sig)

# %%
plt.plot(t[0::100], sig[0::100])

# %%
plt.plot(t[0::100], v[0::100])

# %%
plt.plot(x, np.sin(1 / (2 * np.pi * 10) * (x - t)))

# %%
plt.plot(x[0:100], ana_sig[0:100])

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-978c66d28a44> in <module>()
# ----> 1 plt.plot(x[0:100], ana_v)
#
# /Users/nick/anaconda/lib/python2.7/site-packages/matplotlib/pyplot.pyc in plot(*args, **kwargs)
#    3097         ax.hold(hold)
#    3098     try:
# -> 3099         ret = ax.plot(*args, **kwargs)
#    3100         draw_if_interactive()
#    3101     finally:
#
# /Users/nick/anaconda/lib/python2.7/site-packages/matplotlib/axes/_axes.pyc in plot(self, *args, **kwargs)
#    1371         lines = []
#    1372
# -> 1373         for line in self._get_lines(*args, **kwargs):
#    1374             self.add_line(line)
#    1375             lines.append(line)
#
# /Users/nick/anaconda/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in _grab_next_args(self, *args, **kwargs)
#     302                 return
#     303             if len(remaining) <= 3:
# ...
